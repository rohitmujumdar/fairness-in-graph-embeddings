# %%
# !pip install node2vec
# Out:
# Collecting node2vec
#   Downloading https://files.pythonhosted.org/packages/47/60/af8b5f2ca767e4ee56366886cba1430aab0b1a1c0b188df244098e33ea19/node2vec-0.4.1.tar.gz
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from node2vec) (2.5)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from node2vec) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from node2vec) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from node2vec) (4.41.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.7/dist-packages (from node2vec) (1.0.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx->node2vec) (4.4.2)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (4.2.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->node2vec) (1.15.0)
# Building wheels for collected packages: node2vec
#   Building wheel for node2vec (setup.py) ... done
#   Created wheel for node2vec: filename=node2vec-0.4.1-cp37-none-any.whl size=5734 sha256=0fac46661452ebe95ef709477bd145accc419381feccec0225e3d433179378f2
#   Stored in directory: /root/.cache/pip/wheels/b3/59/ea/22e964f74bb864c5423cf82027a4d69dd65bac0bbf95fd46f5
# Successfully built node2vec
# Installing collected packages: node2vec
# Successfully installed node2vec-0.4.1

# %%
import os
os.chdir('/content/drive/My Drive/wstm/code')
# !pwd
# Out:
# /content/drive/My Drive/wstm/code

# %%
import networkx as nx
from node2vec import Node2Vec

# Import graph
graph = nx.read_gpickle("../data/ml_graph.gpickle")

# Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
node2vec = Node2Vec(graph, dimensions=64, walk_length=30, num_walks=20, workers=4, weight_key='weight')  # Use temp_folder for big graphs

# Embed nodes
model = node2vec.fit(window=10, min_count=1, batch_words=4)  
# Any keywords acceptable by gensim.Word2Vec can be passed, `dimensions` and `workers` are automatically passed (from the Node2Vec constructor)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Computing transition probabilities', max=2625.0, style=Pr…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6398cf399122> in <module>()
#       6
#       7 # Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
# ----> 8 node2vec = Node2Vec(graph, dimensions=10, walk_length=30, num_walks=20, workers=4, weight_key='weight')  # Use temp_folder for big graphs
#       9
#      10 # Embed nodes
#
# /usr/local/lib/python3.7/dist-packages/node2vec/node2vec.py in __init__(self, graph, dimensions, walk_length, num_walks, p, q, weight_key, workers, sampling_strategy, quiet, temp_folder, seed)
#      70             np.random.seed(seed)
#      71
# ---> 72         self._precompute_probabilities()
#      73         self.walks = self._generate_walks()
#      74
#
# /usr/local/lib/python3.7/dist-packages/node2vec/node2vec.py in _precompute_probabilities(self)
#     108                     if destination == source:  # Backwards probability
#     109                         ss_weight = self.graph[current_node][destination].get(self.weight_key, 1) * 1 / p
# --> 110                     elif destination in self.graph[source]:  # If the neighbor is connected to the source
#     111                         ss_weight = self.graph[current_node][destination].get(self.weight_key, 1)
#     112                     else:
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/graph.py in __getitem__(self, n)
#     463         AtlasView({1: {}})
#     464         """
# --> 465         return self.adj[n]
#     466
#     467     def add_node(self, node_for_adding, **attr):
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/coreviews.py in __getitem__(self, name)
#      76     __slots__ = ()  # Still uses AtlasView slots names _atlas
#      77
# ---> 78     def __getitem__(self, name):
#      79         return AtlasView(self._atlas[name])
#      80
#
# KeyboardInterrupt:

# %%
# Look for most similar nodes
print(model.wv.most_similar('user1')) # Output node names are always strings

# Save embeddings for later use
model.wv.save_word2vec_format('../data/ml_node2vec_emebddings.model')

# Save model for later use
model.save('../data/ml_node2vec_model.embeddings')
# Out:
# [('movie119', 0.6638720035552979), ('movie113', 0.5825443267822266), ('user297', 0.5514100790023804), ('user267', 0.5441883206367493), ('user886', 0.5409858226776123), ('user363', 0.532650351524353), ('user715', 0.5288777947425842), ('user343', 0.5277934074401855), ('movie37', 0.5147937536239624), ('movie130', 0.5137654542922974)]
